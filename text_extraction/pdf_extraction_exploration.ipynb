# %% [markdown]
# Purpose of the notebook: compare different opensource packages to extract text from PDFs. Find out which performs best on benchmark examples of sustainability topics in annual reports.

# %%
# Import packages
import pandas as pd

# %% [markdown]
# Use two reports to try out different opensource pdf extraction packages.
#
# Used the 2024 annual reports of AXA and Mercedes Benz
# - https://group.mercedes-benz.com/documents/investors/reports/annual-report/mercedes-benz/mercedes-benz-annual-report-2024-incl-combined-management-report-mbg-ag.pdf
# - https://www-axa-com.cdn.axa-contento-118412.eu/www-axa-com/fd85b507-f97f-4ac5-861b-6b2b90e1c601_AXA_URD2024_EN.pdf
#
# searched for difficult examples to extract the text (tables, images with labeling) to benchmark the performance.

# %% [markdown]
# # PyMuPDF
# https://pymupdf.readthedocs.io/en/latest/

# %%
import pymupdf

mercedes_rep = pymupdf.open("mercedes-2024.pdf")
axa_rep = pymupdf.open("AXA-2024.pdf")

# %%
# extract text from page 132 of the AXA report
axa_text = axa_rep[132].get_text("text")
print(axa_text)
# Out:
# 2
# 5
# 3
# 4
# 6
# 7
# A
# 1
# 4
# Sustainability
# 4.1 General information
# In 2024, AXA presented “Unlock the Future”, its new strategic
# plan for 2024‑2026, focused on growing and strengthening its
# core businesses, around three pillars (driving higher growth,
# scaling excellence and expanding AXA's role in society) and two
# cross‑cutting
# objectives
# (people
# strategy
# and
# robust
# performance). Under its “Expanding AXA's role in society” pillar,
# AXA seeks to contribute to the development of a resilient
# society by focusing on inclusive insurance and climate
# transition.
# On the one hand, AXA aims to proactively address underserved
# customer segments with tailored products and distribution
# channels. On the other hand, the Group wants to build strong
# market capabilities in transition underwriting and transition
# investing, as well as in prevention and adaptation services. The
# successful implementation of this pillar is expected to be driven
# by the skills of AXA's employees and its strong capital
# management. AXA has also defined a set of key performance
# indicators, the “AXA for Progress Index” to measure the impact
# and track progress of its role in society. Please refer to
# Section  4.1.5 - Assessing the impact of AXA's strategy.
#
# 4.1.2.2
# Business model and value chain
# For a detailed description of AXA's business model (including significant markets, group of customers and products, revenue
# breakdown, etc.) refer to the Section  1.2 - Business overview. The following chart provides an illustration of AXA's value chain which is
# further explained in the description of each material IRO.
#
# Downstream stakeholders
# Other stakeholders
# AXA
# Upstream stakeholders
# Investment activities
# INV
# Insurance activities
# INS
# Authorities
# Civil society
#
#
#
#
#
#
#
#
#
#
#
#
# Claim
# management
# Asset and
# investment
# management
# Policy
# administration
# Underwriting
# Marketing,
# Distribution
# and sales
# Product
# and service
# development
#  Policyholders, Customers and Beneﬁciaries
#
#
#
#
#
#
# 
#
# 
# 
#
#
#
#
#
#
#
#
#
#
#
# Business Partners
# Suppliers
#  Stakeholders
# related to
# distribution
# Reinsurers /
# Cedants
# Stakeholders
# related to asset
# management
#  Stakeholders
# related to
# claims
# Investors
# and Lenders
# Employees
#       Investee
# companies
# INS
# INS
# INS
# INS
# INS
# INS
# INV
# INV
# INS
# INS
# INS
# INV
#
# AXA | Universal Registration Document 2024
# 131

# %% [markdown]
# --> PyMuPDF not capable tho extract the images with labeling

# %%
# extract text from page 172 of the AXA report
axa_text = axa_rep[172].get_text("text")
print(axa_text)
# Out:
# 2
# 5
# 3
# 4
# 6
# 7
# A
# 1
# 4
# Sustainability
# 4.2 Environmental information
# This target has been defined with reference to the baseline of
# 47% of suppliers covered by a credible transition plan defined
# in 2023 from which progress is measured. The spend baseline
# for this target covers an estimated 84% of AXA total GenEx and
# IT spend. This target covers the period 2023‑2030. The target is
# monitored and reviewed through an annual review of
# suppliers’ data, including their transition plans, and the metrics
# used are the scope and ambition of the suppliers’ transition
# plans. The expected decarbonization levers and their overall
# quantitative contributions to achieve the GHG emission
# reduction targets are directly at the hands of suppliers, from
# whom AXA expects commitment to a credible transition plan.
# As of September 2024, 48% of AXA GenEx and IT spend
# comprised suppliers who have a climate credible transition
# plan in place.
# Reporting on AXA’s carbon footprint
# Revised comparative figures
# Given 2024 was the first year in which CSRD applied to AXA, it
# has reviewed the calculation of the carbon footprint related to
# its own operations. The main changes relate to the removal of
# entities that are not in the scope of the CSRD but that were
# previously considered (notably entities not controlled), as well
# as the refinement of extrapolation methodology (applied for
# estimating consumption data from AXA's sites of less than 50
# FTEs) that is applied at entity level.
# Additionally, Scope 3 GHG emissions relating to emissions of
# AXA agencies (reported in downstream transportation and
# distribution) have been included in the calculation for 2024.
# The Scope 3.1 GHG emissions related to purchased goods and
# services was extended in 2024 to cover emissions related to all
# GenEx and IT categories (and not solely cloud and network
# services on the main providers). Due to lack of data, the
# retroactive impact on 2019 and 2023 results was assumed to be
# equal to the additional 2024 GHG emissions in this category.
# The Scope 3.2 category related to capital goods also includes
# the emissions from additional equipment such as headsets,
# keyboards, mice and docking stations.
# Consequently, the GHG emissions data for 2019 and 2023
# reported in the previous annual reports have been restated for
# the purpose of this Sustainability Statement.
#
# Energy consumption and mix
# (in MWh, except percentage)
# 2023
# 2024
# Annual %
# target / base
# year (2019)
# Target 2025
# Total fossil energy consumption
# 84,811
# 76,143
#
#
# Share of fossil source in total energy consumption
# 39%
# 36%
#
#
# Consumption from nuclear sources
# 3,722
# 3,649
#
#
# Share of consumption from nuclear
#  source in total energy consumption
#
# 2%
# 2%
#
#
# Fuel consumption for renewable sources
# 3,983
# 3,295
#
#
# Consumption of purchased or acquired electricity,
#  heat, steam, and cooling from renewable sources
#
# 123,953
# 125,945
#
#
# Consumption of self‑generated non‑fuel renewable energy
# 1,261
# 1,468
#
#
# Total renewable energy consumption
# 129,196
# 130,707
#
#
# Total energy consumption
# 217,729
# 210,500
# -34%
# -10%
# Share of renewable energy sources
# 59%
# 62%
#
# Share of renewable electricity sources
# 69%
# 70%
#
# 100%
# AXA | Universal Registration Document 2024
# 171

# %% [markdown]
# --> extracted the content, but not in such a way that it is easy further usable

# %%
### use the option specifically for tables ###

from pprint import pprint

page = axa_rep[172] # get the relevant page of the document
tabs = page.find_tables() # locate and extract any tables on page
print(f"{len(tabs.tables)} found on {page}") # display number of found tables

if tabs.tables:  # at least one table found?
   pprint(tabs[0].extract())  # print content of first table
# Out:
# 1 found on page 172 of AXA-2024.pdf
# [['(in MWh, except percentage) 2023',
#   '2024',
#   'Annual %\ntarget / base\nyear (2019) Target 2025',
#   None],
#  ['Total fossil energy consumption 84,811\n'
#   'Share of fossil source in total energy consumption 39%\n'
#   'Consumption from nuclear sources 3,722\n'
#   'Share of consumption from nuclear\n'
#   '2%\n'
#   'source in total energy consumption\n'
#   'Fuel consumption for renewable sources 3,983\n'
#   'Consumption of purchased or acquired electricity,\n'
#   '123,953\n'
#   'heat, steam, and cooling from renewable sources\n'
#   'Consumption of self‑generated non‑fuel renewable energy 1,261\n'
#   'Total renewable energy consumption 129,196\n'
#   'Total energy consumption 217,729\n'
#   'Share of renewable energy sources 59%\n'
#   'Share of renewable electricity sources 69%',
#   '76,143',
#   '',
#   ''],
#  [None, '36%', '', ''],
#  [None, '3,649', '', ''],
#  [None, '2%', '', ''],
#  [None, '3,295', '', ''],
#  [None, '125,945', '', ''],
#  [None, '1,468', '', ''],
#  [None, '130,707', '', ''],
#  [None, '210,500', '-34% -10%', None],
#  [None, '62%', '', ''],
#  [None, '70%', '', '100%']]

# %% [markdown]
# --> could not extract the table even in the specific function for tables

# %%
# extract text from page 129 of the Mercedes report
mercedes_text = mercedes_rep[129].get_text("text")
print(mercedes_text)
# Out:
# In 2024, there were no material current financial
# effects from these risks and opportunities on the
# profitability, liquidity and capital resources, and
# financial position. From these risks and opportunities,
# no significant risk of a material adjustment to the
# assets and liabilities reported in the Consolidated
# Financial Statements was identified for 2025.
# Annual Report 2024 | Mercedes-Benz Group
# 130
# To Our Shareholders
# Combined Management Report
# Declaration on Corporate Governance
# Consolidated Financial Statements
# Further Information
# Sustainability Statement
# Material impacts, risks and opportunities
# Direction of effect
# Own workforce
# Qualification and further development of employees due to transformation
# actual positive impact
# Remuneration of workforce
# actual positive impact
# Attractive working conditions for employees (work-life balance)
# actual positive impact
# Changes in workplace profiles and work processes due to transformation
# actual negative impact
# Impairment of health and safety
# actual negative impact
# Changes in workplace profiles and work processes due to transformation
# risk
# Work-related accidents and injuries of employees
# risk
# Impact of skills shortage due to demographic trends and qualification requirements
# risk
# Financial risk associated with collective bargaining, strikes and formation of trade unions or employee
# representative bodies
# risk
# Impairment of equal opportunities of employees
# actual negative impact
# Promoting diversity and equal opportunities
# actual positive impact
# Potential child labour in the event of ineffective implementation of compliance processes
# potential negative impact
# Potential forced labour in the event of ineffective implementation of compliance processes
# potential negative impact
# Workers in the value chain
# Impairment due to long working hours1
# actual negative impact
# Inadequate remuneration in the upstream value chain1
# potential negative impact
# Restrictions on employees’ freedom of association1
# potential negative impact
# Restrictions on employees’ collective bargaining rights1
# potential negative impact
# Impairment of health and safety1
# actual negative impact
# Impairment of equal opportunities for employees1
# potential negative impact
# Potential child labour in the upstream value chain1
# potential negative impact
# Potential forced labour in the upstream value chain1
# potential negative impact
# Impairment due to lack of access to drinking water and sanitary facilities1
# potential negative impact
# Capital market-related investment losses related to incidents of human rights violations1
# risk
# Human rights violation in supply chains1
# risk
# 1 These impacts and risks are not material in the value chain of the own business activities.

# %% [markdown]
# --> extracted everything from the table

# %%
# extract text from page 167 of the Mercedes report
mercedes_text = mercedes_rep[167].get_text("text")
print(mercedes_text)
# Out:
# Biodiversity and ecosystems – material impacts, risks and opportunities
# Direction of action
# Time horizon
# Localization
# Value chain position
# Contribution to direct influencing factors to the loss of biodiversity
# Impacts
# Impairment of biological diversity due to CO2 emissions and pollution along the value chain
# negative
# short-term
# local, regional, global
# Impairment of biological diversity due to changes in land and fresh/marine water use in the upstream value chain
# negative
# short-term
# regional
# Impairment of biological diversity in the upstream value chain
# negative
# short-term
# regional
# Spread of invasive alien species in the upstream value chain and the use phase of the vehicles
# negative
# short-term
# regional
# VU  =  Value chain upstream
# OA  =  Own business activity
# VD  =  Value chain downstream
#  =   actual
#
#  =   potential
#
#  =   ESRS compliant target filed
# Consideration of biodiversity and ecosystems in
# strategy and business model
# In addition to the materiality assessment, the
# Mercedes-Benz Group has separately determined the
# resilience of its strategy and business model with
# regard to biodiversity and ecosystems. Detailed infor-
# mation on the scope, key assumptions and stakeholder
# involvement in the materiality assessment is described
# in the chapter General information under Material
# impacts, risks and opportunities and in the section
# Special considerations for identification of material
# biodiversity-related impacts, risks and opportunities of
# this chapter.
# In the resilience analysis, the Mercedes-Benz Group
# assessed its ability to respond to and adapt to external
# influences and crises related to biodiversity risks in the
# upstream value chain and its own business activities
# based on the scenario analysis. This includes the ability
# to manage risks associated with the loss of biodivers-
# ity, including the ability to respond and adapt to
# transition risks, physical and systemic risks. As part of
# the materiality assessment, transition risks, physical
# risks, and systemic risks were examined, with no
# significant risks identified for biodiversity and eco-
# systems. For the scenario analysis, relevant risks were
# selected. Since only transition risks were identified
# as relevant, these were chosen and discussed in the
# scenario analysis.
# The Mercedes-Benz Group analysed the status quo and
# took into account all existing risk mitigation or adapta-
# tion actions. Building on the resilience analysis, stake-
# holders were mapped for each risk. This provides
# an overview of possible stakeholders who can be con-
# sulted in engagement programmes. The resilience
# analysis has shown that the Mercedes-Benz Group
# possesses the capabilities to adapt its strategy and
# business model to the identified challenges related
# to biodiversity and ecosystems.
# Annual Report 2024 | Mercedes-Benz Group
# 168
# To Our Shareholders
# Combined Management Report
# Declaration on Corporate Governance
# Consolidated Financial Statements
# Further Information
# Sustainability Statement

# %% [markdown]
# --> did not extract the images even not with a placeholder

# %% [markdown]
# # PyMuPDF4LLM
# https://pymupdf.readthedocs.io/en/latest/pymupdf4llm/index.html

# %%
import pymupdf4llm

# %%
axa_text = pymupdf4llm.to_markdown("AXA-2024.pdf", pages=[132])
print(axa_text)
# Out:
# In 2024, AXA presented **“** ***Unlock the Future*** **”**, its new strategic
#
# ‑
# plan for 2024 2026, focused on growing and strengthening its
# core businesses, around three pillars (driving higher growth,
# scaling excellence and expanding AXA's role in society) and two
# cross‑cutting objectives (people strategy and robust
# performance). Under its “ *Expanding AXA's role in society* ” pillar,
# AXA seeks to contribute to the development of a resilient
# society by focusing on inclusive insurance and climate
#
# transition.
#
# **4.1.2.2** **Business model and value chain**
#
#
# **Sustainability**
#
# 4.1 General information
#
# On the one hand, AXA aims to proactively address underserved
# customer segments with tailored products and distribution
# channels. On the other hand, the Group wants to build strong
# market capabilities in transition underwriting and transition
# investing, as well as in prevention and adaptation services. The
# successful implementation of this pillar is expected to be driven
# by the skills of AXA's employees and its strong capital
# management. AXA has also defined a set of key performance
# indicators, the *“AXA for Progress Index”* to measure the impact
# and track progress of its role in society. Please refer to
# Section 4.1.5 - Assessing the impact of AXA's strategy.
#
#
#
# For a detailed description of AXA's business model (including significant markets, group of customers and products, revenue
# breakdown, etc.) refer to the Section 1.2 - Business overview. The following chart provides an illustration of AXA's value chain which is
# further explained in the description of each material IRO.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AXA Upstream stakeholders Downstream stakeholders Other stakeholders **INS** Insurance activities **INV** Investment activities
#
# **AXA** **|** **Universal Registration Document 2024** 131
#
#
# -----

# %%
from IPython.display import Markdown
Markdown(axa_text)
# Out:
# In 2024, AXA presented **“** ***Unlock the Future*** **”**, its new strategic
#
# ‑
# plan for 2024 2026, focused on growing and strengthening its
# core businesses, around three pillars (driving higher growth,
# scaling excellence and expanding AXA's role in society) and two
# cross‑cutting objectives (people strategy and robust
# performance). Under its “ *Expanding AXA's role in society* ” pillar,
# AXA seeks to contribute to the development of a resilient
# society by focusing on inclusive insurance and climate
#
# transition.
#
# **4.1.2.2** **Business model and value chain**
#
#
# **Sustainability**
#
# 4.1 General information
#
# On the one hand, AXA aims to proactively address underserved
# customer segments with tailored products and distribution
# channels. On the other hand, the Group wants to build strong
# market capabilities in transition underwriting and transition
# investing, as well as in prevention and adaptation services. The
# successful implementation of this pillar is expected to be driven
# by the skills of AXA's employees and its strong capital
# management. AXA has also defined a set of key performance
# indicators, the *“AXA for Progress Index”* to measure the impact
# and track progress of its role in society. Please refer to
# Section 4.1.5 - Assessing the impact of AXA's strategy.
#
#
#
# For a detailed description of AXA's business model (including significant markets, group of customers and products, revenue
# breakdown, etc.) refer to the Section 1.2 - Business overview. The following chart provides an illustration of AXA's value chain which is
# further explained in the description of each material IRO.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AXA Upstream stakeholders Downstream stakeholders Other stakeholders **INS** Insurance activities **INV** Investment activities
#
# **AXA** **|** **Universal Registration Document 2024** 131
#
#
# -----

# %%
axa_text = pymupdf4llm.to_markdown("AXA-2024.pdf", pages=[172])
print(axa_text)
# Out:
# This target has been defined with reference to the baseline of
# 47% of suppliers covered by a credible transition plan defined
# in 2023 from which progress is measured. The spend baseline
# for this target covers an estimated 84% of AXA total GenEx and
#
# ‑
# IT spend. This target covers the period 2023 2030. The target is
# monitored and reviewed through an annual review of
# suppliers’ data, including their transition plans, and the metrics
# used are the scope and ambition of the suppliers’ transition
# plans. The expected decarbonization levers and their overall
# quantitative contributions to achieve the GHG emission
# reduction targets are directly at the hands of suppliers, from
# whom AXA expects commitment to a credible transition plan.
# As of September 2024, 48% of AXA GenEx and IT spend
# comprised suppliers who have a climate credible transition
# plan in place.
#
# **Reporting on AXA’s carbon footprint**
#
# **Revised comparative figures**
#
# Given 2024 was the first year in which CSRD applied to AXA, it
# has reviewed the calculation of the carbon footprint related to
# its own operations. The main changes relate to the removal of
#
# **Energy consumption and mix**
#
#
# **Sustainability**
#
# 4.2 Environmental information
#
# entities that are not in the scope of the CSRD but that were
# previously considered (notably entities not controlled), as well
# as the refinement of extrapolation methodology (applied for
# estimating consumption data from AXA's sites of less than 50
# FTEs) that is applied at entity level.
#
# Additionally, Scope 3 GHG emissions relating to emissions of
# AXA agencies (reported in downstream transportation and
# distribution) have been included in the calculation for 2024.
# The Scope 3.1 GHG emissions related to purchased goods and
# services was extended in 2024 to cover emissions related to all
#
# GenEx and IT categories (and not solely cloud and network
# services on the main providers). Due to lack of data, the
# retroactive impact on 2019 and 2023 results was assumed to be
# equal to the additional 2024 GHG emissions in this category.
# The Scope 3.2 category related to capital goods also includes
# the emissions from additional equipment such as headsets,
# keyboards, mice and docking stations.
#
# Consequently, the GHG emissions data for 2019 and 2023
# reported in the previous annual reports have been restated for
# the purpose of this Sustainability Statement.
#
#
#
#
#
#
#
#
#
#
# **AXA** **|** **Universal Registration Document 2024** 171
#
#
# -----

# %%
mercedes_text = pymupdf4llm.to_markdown("mercedes-2024.pdf", pages=[129])
print(mercedes_text)
# Out:
# Annual Report 2024 | Mercedes-Benz Group 130
#
# To Our Shareholders **Combined Management Report** Declaration on Corporate Governance Consolidated Financial Statements Further Information
#
# Sustainability Statement
#
#
# In 2024, there were no material current financial
#
# effects from these risks and opportunities on the
#
# profitability, liquidity and capital resources, and
#
# financial position. From these risks and opportunities,
#
# no significant risk of a material adjustment to the
#
# assets and liabilities reported in the Consolidated
#
# Financial Statements was identified for 2025.
#
#
# **Own workforce**
#
# Qualification and further develo p ment of em p lo y ees due to transformation actual p ositive im p act
#
# Remuneration of workforce actual p ositive im p act
#
# Attractive workin g conditions for em p lo y ees ( work-life balance ) actual p ositive im p act
#
# Chan g es in work p lace p rofiles and work p rocesses due to transformation actual ne g ative im p act
#
# Im p airment of health and safet y actual ne g ative im p act
#
# Chan g es in work p lace p rofiles and work p rocesses due to transformation risk
#
# Work-related accidents and in j uries of em p lo y ees risk
#
# Im p act of skills shorta g e due to demo g ra p hic trends and q ualification re q uirements risk
#
# Financial risk associated with collective bargaining, strikes and formation of trade unions or employee
#
# re p resentative bodies risk
#
# Im p airment of e q ual o pp ortunities of em p lo y ees actual ne g ative im p act
#
# Promotin g diversit y and e q ual o pp ortunities actual p ositive im p act
#
# Potential child labour in the event of ineffective im p lementation of com p liance p rocesses p otential ne g ative im p act
#
# Potential forced labour in the event of ineffective im p lementation of com p liance p rocesses p otential ne g ative im p act
#
# **Workers in the value chain**
#
# Im p airment due to lon g workin g hours [1] actual ne g ative im p act
#
# Inade q uate remuneration in the u p stream value chain [1] p otential ne g ative im p act
#
# Restrictions on em p lo y ees’ freedom of association [1] p otential ne g ative im p act
#
# Restrictions on em p lo y ees’ collective bar g ainin g ri g hts [1] p otential ne g ative im p act
#
# Im p airment of health and safet y [1] actual ne g ative im p act
#
# Im p airment of e q ual o pp ortunities for em p lo y ees [1] p otential ne g ative im p act
#
# Potential child labour in the u p stream value chain [1] p otential ne g ative im p act
#
# Potential forced labour in the u p stream value chain [1] p otential ne g ative im p act
#
# Im p airment due to lack of access to drinkin g water and sanitar y facilities [1] p otential ne g ative im p act
#
# Ca p ital market-related investment losses related to incidents of human ri g hts violations [1] risk
#
# Human ri g hts violation in su pp l y chains [1] risk
#
# 1 These impacts and risks are not material in the value chain of the own business activities.
#
#
# -----

# %%
mercedes_text = pymupdf4llm.to_markdown("mercedes-2024.pdf", pages=[167])
print(mercedes_text)
# Out:
# Annual Report 2024 | Mercedes-Benz Group 168
#
# To Our Shareholders **Combined Management Report** Declaration on Corporate Governance Consolidated Financial Statements Further Information
#
# Sustainability Statement
#
# **Contribution to direct influencing factors to the loss of biodiversity**
#
# **Impacts**
#
# VU = Value chain upstream OA = Own business activity VD = Value chain downstream
#
# =  actual =  potential =  ESRS compliant target filed
#
#
# **Consideration of biodiversity and ecosystems in**
# **strategy and business model**
#
# In addition to the materiality assessment, the
#
# Mercedes-Benz Group has separately determined the
#
# resilience of its strategy and business model with
#
# regard to biodiversity and ecosystems. Detailed infor
# mation on the scope, key assumptions and stakeholder
#
# involvement in the materiality assessment is described
#
# in the chapter General information under Material
#
# impacts, risks and opportunities and in the section
#
# Special considerations for identification of material
#
# biodiversity-related impacts, risks and opportunities of
#
# this chapter.
#
#
# In the resilience analysis, the Mercedes-Benz Group
#
# assessed its ability to respond to and adapt to external
#
# influences and crises related to biodiversity risks in the
#
# upstream value chain and its own business activities
#
# based on the scenario analysis. This includes the ability
#
# to manage risks associated with the loss of biodivers
# ity, including the ability to respond and adapt to
#
# transition risks, physical and systemic risks. As part of
#
# the materiality assessment, transition risks, physical
#
# risks, and systemic risks were examined, with no
#
# significant risks identified for biodiversity and eco
# systems. For the scenario analysis, relevant risks were
#
# selected. Since only transition risks were identified
#
# as relevant, these were chosen and discussed in the
#
# scenario analysis.
#
#
# The Mercedes-Benz Group analysed the status quo and
#
# took into account all existing risk mitigation or adapta
# tion actions. Building on the resilience analysis, stake
# holders were mapped for each risk. This provides
#
# an overview of possible stakeholders who can be con
# sulted in engagement programmes. The resilience
#
# analysis has shown that the Mercedes-Benz Group
#
# possesses the capabilities to adapt its strategy and
#
# business model to the identified challenges related
#
# to biodiversity and ecosystems.
#
#
# -----

# %% [markdown]
# # Docling
# https://github.com/docling-project/docling
# https://docling-project.github.io/docling/

# %%
from docling.document_converter import DocumentConverter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from docling.document_converter import DocumentConverter
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\docling\document_converter.py:46
#      44 from docling.pipeline.base_pipeline import BasePipeline
#      45 from docling.pipeline.simple_pipeline import SimplePipeline
# ---> 46 from docling.pipeline.standard_pdf_pipeline import StandardPdfPipeline
#      47 from docling.utils.utils import chunkify
#      49 _log = logging.getLogger(__name__)
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\docling\pipeline\standard_pdf_pipeline.py:21
#      16 from docling.models.document_picture_classifier import (
#      17     DocumentPictureClassifier,
#      18     DocumentPictureClassifierOptions,
#      19 )
#      20 from docling.models.factories import get_ocr_factory, get_picture_description_factory
# ---> 21 from docling.models.layout_model import LayoutModel
#      22 from docling.models.page_assemble_model import PageAssembleModel, PageAssembleOptions
#      23 from docling.models.page_preprocessing_model import (
#      24     PagePreprocessingModel,
#      25     PagePreprocessingOptions,
#      26 )
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\docling\models\layout_model.py:9
#       6 from typing import Optional
#       8 from docling_core.types.doc import DocItemLabel
# ----> 9 from docling_ibm_models.layoutmodel.layout_predictor import LayoutPredictor
#      10 from PIL import Image
#      12 from docling.datamodel.base_models import BoundingBox, Cluster, LayoutPrediction, Page
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\docling_ibm_models\layoutmodel\layout_predictor.py:12
#      10 import numpy as np
#      11 import torch
# ---> 12 import torchvision.transforms as T
#      13 from PIL import Image
#      14 from transformers import RTDetrForObjectDetection, RTDetrImageProcessor
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\models\__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\models\convnext.py:9
#       6 from torch.nn import functional as F
#       8 from ..ops.misc import Conv2dNormActivation, Permute
# ----> 9 from ..ops.stochastic_depth import StochasticDepth
#      10 from ..transforms._presets import ImageClassification
#      11 from ..utils import _log_api_usage_once
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\ops\__init__.py:23
#      21 from .giou_loss import generalized_box_iou_loss
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#      25 from .ps_roi_pool import ps_roi_pool, PSRoIPool
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\ops\poolers.py:10
#       7 from torchvision.ops.boxes import box_area
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      13 # copying result_idx_in_level to a specific index in result[]
#      14 # is not supported by ONNX tracing yet.
#      15 # _onnx_merge_levels() is an implementation supported by ONNX
#      16 # that merges the levels to the right indices
#      17 @torch.jit.unused
#      18 def _onnx_merge_levels(levels: Tensor, unmerged_results: List[Tensor]) -> Tensor:
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\ops\roi_align.py:7
#       5 import torch.fx
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#       9 from torch.nn.modules.utils import _pair
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_dynamo\__init__.py:2
#       1 import torch
# ----> 2 from . import allowed_functions, convert_frame, eval_frame, resume_execution
#       3 from .backends.registry import list_backends, lookup_backend, register_backend
#       4 from .code_context import code_context
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_dynamo\allowed_functions.py:25
#      21     pass
#      24 import torch
# ---> 25 import torch._functorch.deprecated as deprecated_func
#      26 from torch.fx._symbolic_trace import is_fx_tracing
#      28 from . import config
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_functorch\deprecated.py:113
#     111 setup_docs(vmap, apis.vmap, 'torch.vmap')
#     112 setup_docs(grad, apis.grad)
# --> 113 setup_docs(grad_and_value)
#     114 setup_docs(vjp)
#     115 setup_docs(jvp)
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_functorch\deprecated.py:44, in setup_docs(functorch_api, torch_func_api, new_api_name)
#      42 api_name = functorch_api.__name__
#      43 if torch_func_api is None:
# ---> 44     torch_func_api = getattr(_impl, api_name)
#      45 # See https://docs.python.org/3/using/cmdline.html#cmdoption-OO
#      46 if torch_func_api.__doc__ is None:
#
# AttributeError: module 'torch._functorch.eager_transforms' has no attribute 'grad_and_value'

# %%
from docling.document_converter import DocumentConverter

source = "https://group.mercedes-benz.com/documents/investors/reports/annual-report/mercedes-benz/mercedes-benz-annual-report-2024-incl-combined-management-report-mbg-ag.pdf"  # document per local path or URL
converter = DocumentConverter()
result = converter.convert(source, pages=[128])
print(result.document.export_to_markdown())  # output: "## Docling Technical Report[...]"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from docling.document_converter import DocumentConverter
#       3 source = "https://group.mercedes-benz.com/documents/investors/reports/annual-report/mercedes-benz/mercedes-benz-annual-report-2024-incl-combined-management-report-mbg-ag.pdf"  # document per local path or URL
#       4 converter = DocumentConverter()
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\docling\document_converter.py:46
#      44 from docling.pipeline.base_pipeline import BasePipeline
#      45 from docling.pipeline.simple_pipeline import SimplePipeline
# ---> 46 from docling.pipeline.standard_pdf_pipeline import StandardPdfPipeline
#      47 from docling.utils.utils import chunkify
#      49 _log = logging.getLogger(__name__)
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\docling\pipeline\standard_pdf_pipeline.py:21
#      16 from docling.models.document_picture_classifier import (
#      17     DocumentPictureClassifier,
#      18     DocumentPictureClassifierOptions,
#      19 )
#      20 from docling.models.factories import get_ocr_factory, get_picture_description_factory
# ---> 21 from docling.models.layout_model import LayoutModel
#      22 from docling.models.page_assemble_model import PageAssembleModel, PageAssembleOptions
#      23 from docling.models.page_preprocessing_model import (
#      24     PagePreprocessingModel,
#      25     PagePreprocessingOptions,
#      26 )
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\docling\models\layout_model.py:9
#       6 from typing import Optional
#       8 from docling_core.types.doc import DocItemLabel
# ----> 9 from docling_ibm_models.layoutmodel.layout_predictor import LayoutPredictor
#      10 from PIL import Image
#      12 from docling.datamodel.base_models import BoundingBox, Cluster, LayoutPrediction, Page
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\docling_ibm_models\layoutmodel\layout_predictor.py:12
#      10 import numpy as np
#      11 import torch
# ---> 12 import torchvision.transforms as T
#      13 from PIL import Image
#      14 from transformers import RTDetrForObjectDetection, RTDetrImageProcessor
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\models\__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\models\convnext.py:9
#       6 from torch.nn import functional as F
#       8 from ..ops.misc import Conv2dNormActivation, Permute
# ----> 9 from ..ops.stochastic_depth import StochasticDepth
#      10 from ..transforms._presets import ImageClassification
#      11 from ..utils import _log_api_usage_once
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\ops\__init__.py:23
#      21 from .giou_loss import generalized_box_iou_loss
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#      25 from .ps_roi_pool import ps_roi_pool, PSRoIPool
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\ops\poolers.py:10
#       7 from torchvision.ops.boxes import box_area
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      13 # copying result_idx_in_level to a specific index in result[]
#      14 # is not supported by ONNX tracing yet.
#      15 # _onnx_merge_levels() is an implementation supported by ONNX
#      16 # that merges the levels to the right indices
#      17 @torch.jit.unused
#      18 def _onnx_merge_levels(levels: Tensor, unmerged_results: List[Tensor]) -> Tensor:
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torchvision\ops\roi_align.py:7
#       5 import torch.fx
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#       9 from torch.nn.modules.utils import _pair
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_dynamo\__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import config, convert_frame, eval_frame, resume_execution
#      14 from .backends.registry import list_backends, lookup_backend, register_backend
#      15 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_dynamo\convert_frame.py:52
#      50 from torch._C._dynamo.guards import GlobalStateGuard
#      51 from torch._dynamo.distributed import get_compile_pg
# ---> 52 from torch._dynamo.symbolic_convert import TensorifyState
#      53 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      54 from torch._logging import structured
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_dynamo\symbolic_convert.py:52
#      50 import torch
#      51 import torch._logging
# ---> 52 from torch._dynamo.exc import TensorifyScalarRestartAnalysis
#      53 from torch._guards import tracing, TracingContext
#      54 from torch.fx.experimental.symbolic_shapes import guard_bool
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_dynamo\exc.py:41
#      38 import torch._guards
#      40 from . import config
# ---> 41 from .utils import counters
#      44 if TYPE_CHECKING:
#      45     import types
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_dynamo\utils.py:68
#      65 from typing_extensions import Literal, TypeIs
#      67 import torch
# ---> 68 import torch._functorch.config
#      69 import torch.fx.experimental.symbolic_shapes
#      70 import torch.utils._pytree as pytree
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_functorch\config.py:40
#      37 # Applies CSE to the graph before partitioning
#      38 cse = True
# ---> 40 from torch._inductor.config import is_fbcode
#      43 enable_autograd_cache: bool = Config(
#      44     justknob="pytorch/remote_cache:enable_local_autograd_cache",
#      45     env_name_force="TORCHINDUCTOR_AUTOGRAD_CACHE",
#      46     default=True,
#      47 )
#      50 def remote_autograd_cache_default() -> Optional[bool]:
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_inductor\__init__.py:9
#       6 import os
#       7 from typing import Any, IO, Optional, TYPE_CHECKING, Union
# ----> 9 import torch._inductor.config
#      10 import torch.fx
#      13 if TYPE_CHECKING:
#
# File c:\Users\julia\OneDrive - UT Cloud\Thesis\esg_extraction\.venv\Lib\site-packages\torch\_inductor\config.py:202
#     195 b2b_gemm_pass = False
#     197 # register custom graph optimization pass hook. so far, pre/post passes are
#     198 # only applied before/after pattern_matcher in post_grad_passes.
#     199 #
#     200 # Implement CustomGraphPass to allow Inductor to graph compiled artifacts
#     201 # to which your custom passes have been applied:
# --> 202 post_grad_custom_pre_pass: torch._inductor.custom_graph_pass.CustomGraphPassType = None
#     203 post_grad_custom_post_pass: torch._inductor.custom_graph_pass.CustomGraphPassType = None
#     205 # Registers a custom joint graph pass.
#
# AttributeError: partially initialized module 'torch._inductor' has no attribute 'custom_graph_pass' (most likely due to a circular import)
